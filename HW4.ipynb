# %% [markdown]
# Name: Kevin Paganini
# Class: MA 3320 001
# Problem: PA 3
# Date: 1.12.2023
# Professor: Dr. Cox

# %% [markdown]
# 14. List all the steps used to search for 7 in the sequence given in Exercise 13 for both a linear search and a binary search.
#
# Sequence: $1, 3, 4, 5, 6, 8, 9, 11$
#
# Linear search: Goes through list one by one (for loop or while loop) and does not find $7$.
# Visits zeroth element, compares to $7$, it is not equal so continues to next iteration
# Visits first element, compares to $7$, it is not equal so continues to next iteration
# ...
# Visits $7th$ element, compares to $7$, it is not equal so linear search fails and returns $-1$.
#
#
# Trace table:
#
# | iteration (i)                      | 0     | 1     | 2     | 3     | 4     | 5     | 6     | 7     | 8    |
# |------------------------------------|-------|-------|-------|-------|-------|-------|-------|-------|------|
# | Value of element at index i        | 1     | 3     | 4     | 5     | 6     | 8     | 9     | 11    | -    |
# | Does target equal element at index | False | False | False | False | False | False | False | False | -    |
# | exit condition ( i >= n)           | False | False | False | False | False | False | False | False | True |
#
#
# Binary Search:
# To start the algorithm, integers $i$ and $j$ are initialized to $0$ and $8$ (size of the list) respecitvely. Then we enter a while loop. The condition of the while loop is that $i < j$.
# Then on iteration one of the loop a new integer $m$ is made which is $i + j / 2$. In our case, since the list length is $8$, $m = (0 + 8) / 2 = 4$. Then we check whether $7$ is greater than the element at the index $m$. Since $7$ is bigger than $6$, we set $i$ to $m + 1$, $i = 4 + 1 = 5$. Now we go back to the top of the while loop and check the condition again. Since $i$ is $5$ now and $j$ is still $8$ we loop through again. We calculate $m$ to be $(5 + 8) / 2 = 6$ (since there is a floor function). Comparing $7$ to the element at index $6$, $7 < 9$. So, we set $j$ equal to $m$. Now we go back to the top of the loop again and check the codition again. $i = 5$ and $j = 6$, so we enter the loop again. We calculate $m$ to be $5$. We check index $5$ and compare to $7$: $7 < 8$, so we set $i$ to be equal to $m + 1$, $i = 6$. $i$ and $j$ are now both $6$, so the while loop terminates. We then check if the element at index $i$ is equal to $7$, it is not so we return $-1$.
#
# | Iteration  | 0                    | 1 | 2 | 3                                                                           |
# |------------|----------------------|---|---|-----------------------------------------------------------------------------|
# | value of i | 0                    | 4 | 4 | 5                                                                           |
# | value of j | 7                    | 7 | 5 | 5                                                                           |
# | value of m | -                    | 3 | 5 | 4                                                                           |
# | Notes      | 7 because zero-based | - | - | Loop now exits because  i is not less than j.  It did not find the element. |

# %% [markdown]
# 18. Describe an algorithm that locates the last occurrence of the smallest element in a finite list of integers, where the integers in the list are not necessarily distinct.
#
# A simple algorithm could solve this problem. First I would initialize a variable named min_val and store the zeroth element of the list. I would initialize another variable named min_index and store $0$ there, i.e. the index of min_val. Then I would loop through the list from the first (second in non-cs terms) element to the $n_{th}$ element. Each time looping through I would check to see if the element at the index is smaller or equal to the min_val. If it is, then I will save the element at the current index to min_val and save the current index to min_index. At the end of the loop I will then return min_index. The time complexity of this algorithm is O(n).
#
# Here is a procedure doing what is described above:
#
# ```
# procedure min_index(a_0, a_1, ..., a_n: finite list of integers):
#     min_val := a_0 {Store the zeroth value as the minimum value of the list}
#     min_index := 0 {Store the index of the zeroth value}
#
#     for i := 1 to n {n is the length of the list}
#         if element at i less than or equal to min_val:
#             then min_val := element at i, min_index := i
#
#     return min_index
#
#
# ```

# %% [markdown]
# 20. Show that if there were a coin worth 12 cents, the cashier’s algorithm using quarters, 12-cent coins, dimes, nickels, and pennies would not always produce change using the fewest coins possible.
#
# Take the change needed to be given out to be 15 cents. If the cashiers algorithm was used it would choose 12-cents (the highest value possible that fits in) and then it would have to pick 3 pennies, for a total of 4 coins. The optimal choice to minimize the amount of coins used would have been a dime and a nickel. Since the cashiers algorithm cannot look ahead, it chooses an inoptimal path. Change given out with 12 cents = 4, while change given out without 12 cents is 2 in this case. Another example of a coin system with 12 cents solving the problem inoptimally is when change needed to be given out is 21 cents.

# %% [markdown]
# ### Would a standard coin system or one with a 12-cent coin minimize the amount of change needed to be given on average if both were to use the cashiers algorithm

# %%
def cash_algo_w_12(change, i):
    x = [25, 12, 10, 5, 1]
    num_coins = 0
    if i % 10000 == 0:
        print(f'Change with 12')
    index = 0
    while change != 0:
        if i % 10000 == 0:
            print(f'  Iteration: {index}: {change}')
        if change - x[0] >= 0:
            change = change - x[0]
            
        elif change - x[1] >= 0:
            change = change - x[1]
            
        elif change - x[2] >= 0:
            change = change - x[2]
            
        elif change - x[3] >= 0:
            change = change - x[3]
            
        elif change - x[4] >= 0:
            change = change - x[4]
        
            
        num_coins = num_coins + 1
        index += 1
    return num_coins    
            
def cash_algo_wo_12(change, i):
    x = [25, 10, 5, 1]
    num_coins = 0
    if i % 10000 == 0:
        print(f'Change with 12')
    index = 0
    while change != 0:
        if i % 10000 == 0:
            print(f'  Iteration: {index}: {change}')
        if change - x[0] >= 0:
            change = change - x[0]
        elif change - x[1] >= 0:
            change = change - x[1]
        elif change - x[2] >= 0:
            change = change - x[2]
        elif change - x[3] >= 0:
            change = change - x[3]
        
        num_coins = num_coins + 1
        index += 1
    return num_coins

# %%
import random
results_w_12 = []
results_wo_12 = []
for i in range(100000):
   
    x = random.randint(1, 100)
    if i % 10000 == 0:
        print(f'Starting change for both algorithms: {x}')
        
    _result_wo_12 = cash_algo_wo_12(x, i)
    _result_w_12 = cash_algo_w_12(x, i)
    if i % 10000 == 0:
        print("*******************************************")
    results_w_12.append(_result_w_12)
    results_wo_12.append(_result_wo_12)
# Out:
# Starting change for both algorithms: 72
# Change with 12
#   Iteration: 0: 72
#   Iteration: 1: 47
#   Iteration: 2: 22
#   Iteration: 3: 12
#   Iteration: 4: 2
#   Iteration: 5: 1
# Change with 12
#   Iteration: 0: 72
#   Iteration: 1: 47
#   Iteration: 2: 22
#   Iteration: 3: 10
# *******************************************
# Starting change for both algorithms: 86
# Change with 12
#   Iteration: 0: 86
#   Iteration: 1: 61
#   Iteration: 2: 36
#   Iteration: 3: 11
#   Iteration: 4: 1
# Change with 12
#   Iteration: 0: 86
#   Iteration: 1: 61
#   Iteration: 2: 36
#   Iteration: 3: 11
#   Iteration: 4: 1
# *******************************************
# Starting change for both algorithms: 1
# Change with 12
#   Iteration: 0: 1
# Change with 12
#   Iteration: 0: 1
# *******************************************
# Starting change for both algorithms: 18
# Change with 12
#   Iteration: 0: 18
#   Iteration: 1: 8
#   Iteration: 2: 3
#   Iteration: 3: 2
#   Iteration: 4: 1
# Change with 12
# ...

# %%
import numpy as np

w12 = np.array(results_w_12)
wo12 = np.array(results_wo_12)

print(f'Average number of coins needed to fulfill change between 1 and 100 with a 12 cent coin: {w12.mean()}')
print(f'Average number of coins needed to fulfill change between 1 and 100 with standard coins only: {wo12.mean()}')
# Out:
# Average number of coins needed to fulfill change between 1 and 100 with a 12 cent coin: 4.34062
# Average number of coins needed to fulfill change between 1 and 100 with standard coins only: 4.7413

# %% [markdown]
# ### Conclusion
#
# The cashiers algorithm with a 12 cent coin does not solve the change problem optimally in some cases. However, through trials one can see that if there were a 12 cent coin and the cashiers algorithm would be used it would on average use less coins than a standard coin system. A hypotheses this leads me to is that each coin that you add decreases the average amount of coins needed to be given out using the cashiers algorithm.
